# %%
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_process import arma_generate_sample
from statsmodels.tsa.arima.model import ARIMA

# %%
ar_coef  = np.array([0.8,-0.2])
ma_coef = np.array([0.9,0.5,-.3])
arma_ts = arma_generate_sample(
ar=np.r_[1,-ar_coef], ma=np.r_[1,ma_coef], nsample =100)
plt.figure(figsize=(12,4))
plt.plot(arma_ts)

# %%
model_good = ARIMA(arma_ts, order=(2, 3, 0))
model_good_res = model_good.fit()
print(model_good_res.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  100
# Model:                 ARIMA(2, 3, 0)   Log Likelihood                -207.244
# Date:                Fri, 13 May 2022   AIC                            420.488
# Time:                        23:24:12   BIC                            428.212
# Sample:                             0   HQIC                           423.611
#                                 - 100
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2836      0.114     -2.488      0.013      -0.507      -0.060
# ar.L2         -0.2731      0.103     -2.661      0.008      -0.474      -0.072
# sigma2         4.1915      0.736      5.697      0.000       2.750       5.633
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.59   Jarque-Bera (JB):                 1.87
# Prob(Q):                              0.11   Prob(JB):                         0.39
# Heteroskedasticity (H):               1.69   Skew:                             0.14
# Prob(H) (two-sided):                  0.15   Kurtosis:                         2.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model_bad = ARIMA(arma_ts, order=(2, 3, 0))
model_bad_res = model_bad.fit()
print(model_bad_res.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  100
# Model:                 ARIMA(2, 3, 0)   Log Likelihood                -207.244
# Date:                Fri, 13 May 2022   AIC                            420.488
# Time:                        23:24:31   BIC                            428.212
# Sample:                             0   HQIC                           423.611
#                                 - 100
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2836      0.114     -2.488      0.013      -0.507      -0.060
# ar.L2         -0.2731      0.103     -2.661      0.008      -0.474      -0.072
# sigma2         4.1915      0.736      5.697      0.000       2.750       5.633
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.59   Jarque-Bera (JB):                 1.87
# Prob(Q):                              0.11   Prob(JB):                         0.39
# Heteroskedasticity (H):               1.69   Skew:                             0.14
# Prob(H) (two-sided):                  0.15   Kurtosis:                         2.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
